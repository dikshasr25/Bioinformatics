# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
#
#
#
# Comparing several ML algorithms for build regression models of IDO1 inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.1.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %%
# Out:
# --2021-01-22 14:57:46--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2021-01-22 14:57:46--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’
#
# acetylcholinesteras 100%[===================>]   7.98M  46.7MB/s    in 0.2s
#
# 2021-01-22 14:57:47 (46.7 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv’ saved [8363909/8363909]

# %%
df = pd.read_csv('/content/bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (3406, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (3406, 155)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#  98%|█████████▊| 41/42 [00:40<00:00,  1.65it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002433 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 465
# [LightGBM] [Info] Number of data points in the train set: 2724, number of used features: 155
# [LightGBM] [Info] Start training from score 6.220850
# 100%|██████████| 42/42 [00:41<00:00,  1.02it/s]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#  98%|█████████▊| 41/42 [00:37<00:00,  1.87it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002368 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 465
# [LightGBM] [Info] Number of data points in the train set: 2724, number of used features: 155
# [LightGBM] [Info] Start training from score 6.220850
# 100%|██████████| 42/42 [00:37<00:00,  1.11it/s]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                        Adjusted R-Squared  \
# Model
# DecisionTreeRegressor                                0.84
# ExtraTreeRegressor                                   0.84
# ExtraTreesRegressor                                  0.84
# GaussianProcessRegressor                             0.84
# XGBRegressor                                         0.83
# RandomForestRegressor                                0.81
# MLPRegressor                                         0.81
# BaggingRegressor                                     0.80
# HistGradientBoostingRegressor                        0.76
# LGBMRegressor                                        0.75
# SVR                                                  0.68
# NuSVR                                                0.68
# KNeighborsRegressor                                  0.68
# GradientBoostingRegressor                            0.61
# TransformedTargetRegressor                           0.53
# LinearRegression                                     0.53
# Ridge                                                0.53
# RidgeCV                                              0.53
# LassoCV                                              0.52
# ElasticNetCV                                         0.52
# BayesianRidge                                        0.52
# HuberRegressor                                       0.51
# SGDRegressor                                         0.50
# LinearSVR                                            0.49
# PoissonRegressor                                     0.47
# TweedieRegressor                                     0.42
# GammaRegressor                                       0.41
# OrthogonalMatchingPursuit                            0.40
# OrthogonalMatchingPursuitCV                          0.40
# AdaBoostRegressor                                    0.37
# LassoLarsIC                                          0.33
# LassoLarsCV                                          0.32
# LarsCV                                               0.31
# PassiveAggressiveRegressor                           0.22
# ElasticNet                                          -0.04
# Lasso                                               -0.06
# DummyRegressor                                      -0.06
# LassoLars                                           -0.06
# Lars                                               -17.82
# KernelRidge                                        -18.88
# RANSACRegressor               -14200065935778376581120.00
#
#                                                 R-Squared            RMSE  \
# Model
# DecisionTreeRegressor                                0.85            0.57
# ExtraTreeRegressor                                   0.85            0.57
# ExtraTreesRegressor                                  0.85            0.57
# GaussianProcessRegressor                             0.85            0.57
# XGBRegressor                                         0.84            0.58
# RandomForestRegressor                                0.83            0.61
# MLPRegressor                                         0.82            0.62
# BaggingRegressor                                     0.81            0.63
# HistGradientBoostingRegressor                        0.77            0.70
# LGBMRegressor                                        0.76            0.71
# SVR                                                  0.70            0.80
# NuSVR                                                0.70            0.80
# KNeighborsRegressor                                  0.69            0.80
# GradientBoostingRegressor                            0.63            0.88
# TransformedTargetRegressor                           0.56            0.97
# LinearRegression                                     0.56            0.97
# Ridge                                                0.56            0.97
# RidgeCV                                              0.56            0.97
# LassoCV                                              0.55            0.97
# ElasticNetCV                                         0.55            0.97
# BayesianRidge                                        0.55            0.98
# HuberRegressor                                       0.54            0.98
# SGDRegressor                                         0.53            0.99
# LinearSVR                                            0.52            1.01
# PoissonRegressor                                     0.50            1.02
# TweedieRegressor                                     0.45            1.08
# GammaRegressor                                       0.44            1.08
# OrthogonalMatchingPursuit                            0.43            1.10
# OrthogonalMatchingPursuitCV                          0.43            1.10
# AdaBoostRegressor                                    0.41            1.12
# LassoLarsIC                                          0.37            1.15
# LassoLarsCV                                          0.36            1.17
# LarsCV                                               0.35            1.17
# PassiveAggressiveRegressor                           0.26            1.25
# ElasticNet                                           0.01            1.44
# Lasso                                                0.00            1.45
# DummyRegressor                                       0.00            1.45
# LassoLars                                            0.00            1.45
# Lars                                               -16.75            6.13
# KernelRidge                                        -17.75            6.30
# RANSACRegressor               -13391762513066054385664.00 168254271562.39
#
#                                Time Taken
# Model
# DecisionTreeRegressor                0.14
# ExtraTreeRegressor                   0.17
# ExtraTreesRegressor                  4.43
# GaussianProcessRegressor             3.29
# XGBRegressor                         0.32
# RandomForestRegressor                3.25
# MLPRegressor                         4.84
# BaggingRegressor                     0.38
# HistGradientBoostingRegressor        1.40
# LGBMRegressor                        0.33
# SVR                                  2.00
# NuSVR                                2.20
# KNeighborsRegressor                  0.25
# GradientBoostingRegressor            1.29
# TransformedTargetRegressor           0.07
# LinearRegression                     0.09
# Ridge                                0.05
# RidgeCV                              0.14
# LassoCV                              3.38
# ElasticNetCV                         4.85
# BayesianRidge                        0.15
# HuberRegressor                       0.52
# SGDRegressor                         0.14
# LinearSVR                            0.75
# PoissonRegressor                     0.84
# TweedieRegressor                     0.26
# GammaRegressor                       0.36
# OrthogonalMatchingPursuit            0.06
# OrthogonalMatchingPursuitCV          0.12
# AdaBoostRegressor                    0.37
# LassoLarsIC                          0.11
# LassoLarsCV                          0.20
# LarsCV                               0.89
# PassiveAggressiveRegressor           0.09
# ElasticNet                           0.04
# Lasso                                0.12
# DummyRegressor                       0.03
# LassoLars                            0.09
# Lars                                 0.21
# KernelRidge                          1.08
# RANSACRegressor                      1.71

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                       Adjusted R-Squared  \
# Model
# HistGradientBoostingRegressor                       0.48
# LGBMRegressor                                       0.47
# SVR                                                 0.45
# NuSVR                                               0.45
# RandomForestRegressor                               0.44
# MLPRegressor                                        0.43
# XGBRegressor                                        0.43
# KNeighborsRegressor                                 0.42
# BaggingRegressor                                    0.42
# GradientBoostingRegressor                           0.40
# TransformedTargetRegressor                          0.34
# LinearRegression                                    0.34
# RidgeCV                                             0.34
# ElasticNetCV                                        0.34
# Ridge                                               0.34
# LassoCV                                             0.34
# BayesianRidge                                       0.33
# SGDRegressor                                        0.32
# HuberRegressor                                      0.31
# LinearSVR                                           0.28
# PoissonRegressor                                    0.28
# ExtraTreesRegressor                                 0.23
# DecisionTreeRegressor                               0.23
# TweedieRegressor                                    0.22
# GammaRegressor                                      0.21
# OrthogonalMatchingPursuitCV                         0.19
# OrthogonalMatchingPursuit                           0.19
# ExtraTreeRegressor                                  0.18
# AdaBoostRegressor                                   0.16
# LassoLarsIC                                         0.10
# LarsCV                                              0.10
# LassoLarsCV                                         0.07
# PassiveAggressiveRegressor                         -0.01
# ElasticNet                                         -0.28
# Lasso                                              -0.30
# DummyRegressor                                     -0.30
# LassoLars                                          -0.30
# GaussianProcessRegressor                           -5.73
# KernelRidge                                       -21.09
# Lars                                              -23.41
# RANSACRegressor               -9300124950428415688704.00
#
#                                                R-Squared            RMSE  \
# Model
# HistGradientBoostingRegressor                       0.60            0.97
# LGBMRegressor                                       0.59            0.98
# SVR                                                 0.58            0.99
# NuSVR                                               0.57            0.99
# RandomForestRegressor                               0.57            1.00
# MLPRegressor                                        0.56            1.01
# XGBRegressor                                        0.56            1.01
# KNeighborsRegressor                                 0.55            1.02
# BaggingRegressor                                    0.55            1.02
# GradientBoostingRegressor                           0.53            1.04
# TransformedTargetRegressor                          0.49            1.09
# LinearRegression                                    0.49            1.09
# RidgeCV                                             0.49            1.09
# ElasticNetCV                                        0.49            1.09
# Ridge                                               0.49            1.09
# LassoCV                                             0.49            1.09
# BayesianRidge                                       0.48            1.09
# SGDRegressor                                        0.48            1.10
# HuberRegressor                                      0.46            1.11
# LinearSVR                                           0.45            1.13
# PoissonRegressor                                    0.44            1.13
# ExtraTreesRegressor                                 0.41            1.17
# DecisionTreeRegressor                               0.40            1.17
# TweedieRegressor                                    0.40            1.18
# GammaRegressor                                      0.39            1.18
# OrthogonalMatchingPursuitCV                         0.37            1.20
# OrthogonalMatchingPursuit                           0.37            1.20
# ExtraTreeRegressor                                  0.37            1.21
# AdaBoostRegressor                                   0.35            1.22
# LassoLarsIC                                         0.30            1.27
# LarsCV                                              0.30            1.27
# LassoLarsCV                                         0.28            1.29
# PassiveAggressiveRegressor                          0.22            1.34
# ElasticNet                                          0.01            1.51
# Lasso                                              -0.01            1.52
# DummyRegressor                                     -0.01            1.52
# LassoLars                                          -0.01            1.52
# GaussianProcessRegressor                           -4.20            3.47
# KernelRidge                                       -16.06            6.28
# Lars                                              -17.85            6.60
# RANSACRegressor               -7183356422797865779200.00 128871802560.43
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        1.15
# LGBMRegressor                        0.29
# SVR                                  1.13
# NuSVR                                0.99
# RandomForestRegressor                4.06
# MLPRegressor                         4.86
# XGBRegressor                         0.29
# KNeighborsRegressor                  0.06
# BaggingRegressor                     0.36
# GradientBoostingRegressor            1.26
# TransformedTargetRegressor           0.07
# LinearRegression                     0.12
# RidgeCV                              0.16
# ElasticNetCV                         4.94
# Ridge                                0.04
# LassoCV                              4.94
# BayesianRidge                        0.11
# SGDRegressor                         0.13
# HuberRegressor                       0.19
# LinearSVR                            0.77
# PoissonRegressor                     0.26
# ExtraTreesRegressor                  4.43
# DecisionTreeRegressor                0.15
# TweedieRegressor                     0.40
# GammaRegressor                       0.27
# OrthogonalMatchingPursuitCV          0.08
# OrthogonalMatchingPursuit            0.03
# ExtraTreeRegressor                   0.17
# AdaBoostRegressor                    0.33
# LassoLarsIC                          0.13
# LarsCV                               0.53
# LassoLarsCV                          0.20
# PassiveAggressiveRegressor           0.06
# ElasticNet                           0.04
# Lasso                                0.06
# DummyRegressor                       0.03
# LassoLars                            0.04
# GaussianProcessRegressor             2.11
# KernelRidge                          0.59
# Lars                                 0.09
# RANSACRegressor                      1.82

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
